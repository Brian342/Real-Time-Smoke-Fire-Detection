# %% [markdown]
# <a href="https://colab.research.google.com/github/Brian342/Real-Time-Smoke-Fire-Detection/blob/main/Fire_smoke_Detection.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Download dataset
# !wget -O dataset.zip "https://china.scidb.cn/download?fileId=7c6af6ff0d3edca57e82c5a9bd1aa7a3&traceId=6b530992-4636-4245-b6f2-94cdbbd11639"
# !unzip -q dataset.zip -d ./my_data
# Out:
# --2026-01-13 16:28:00--  https://china.scidb.cn/download?fileId=7c6af6ff0d3edca57e82c5a9bd1aa7a3&traceId=6b530992-4636-4245-b6f2-94cdbbd11639
# Resolving china.scidb.cn (china.scidb.cn)... 60.245.194.35
# Connecting to china.scidb.cn (china.scidb.cn)|60.245.194.35|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 31915027490 (30G) [application/octet-stream]
# Saving to: ‘dataset.zip’
#
# dataset.zip           0%[                    ] 117.05M  4.96MB/s    eta 1h 57m

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
# !mv /content/dataset.zip /content/drive/MyDrive/

# %%
# !wget -O dataset1.zip "https://china.scidb.cn/download?fileId=85bad3972ed60e0a20a790032c0d85fb&traceId=6b530992-4636-4245-b6f2-94cdbbd11639"
# !unzip -q dataset1.zip -d ./my_data
